# %% [markdown]
# # Correlation between attrition and other variables(features)

# %%
import pandas as pd

# %%
df = pd.read_csv("general_data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %% [markdown]
# ### convert attirtion data to numerical values

# %%
df['Attrition_numerical'] = pd.factorize(df.Attrition)[0]

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  Over18  \
# 0          2  Life Sciences              1           1  Female  ...       Y
# 1          1  Life Sciences              1           2  Female  ...       Y
# 2          4          Other              1           3    Male  ...       Y
# 3          5  Life Sciences              1           4    Male  ...       Y
# 4          1        Medical              1           5    Male  ...       Y
#
# ...

# %%
df.Attrition.value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
df.Attrition_numerical.value_counts()
# Out:
# 0    3699
# 1     711
# Name: Attrition_numerical, dtype: int64

# %%
from scipy.stats import pearsonr

# %% [markdown]
# ### Negative correlation between Attrition and Age

# %%
stats,p = pearsonr(df.Attrition_numerical,df.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698115076 0.03842748490600132

# %% [markdown]
# ### Negative correlation between Attrition and DistanceFromHome

# %%
stats,p = pearsonr(df.Attrition_numerical,df.DistanceFromHome)
print(stats,p)
# Out:
# -0.009730141010179667 0.5182860428050771

# %% [markdown]
# ### Negative correlation between Attrition and JobLevel

# %%
stats,p = pearsonr(df.Attrition_numerical,df.JobLevel)
print(stats,p)
# Out:
# -0.010289713287495077 0.49451717271828405

# %% [markdown]
# ### Negative correlation between Attrition and Monthly income

# %%
stats,p = pearsonr(df.Attrition_numerical,df.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698115076 0.03842748490600132

# %% [markdown]
# ### Positive correlation between Attrition and PercentSalaryHike

# %%
stats,p = pearsonr(df.Attrition_numerical,df.PercentSalaryHike)
print(stats,p)
# Out:
# 0.032532594891053535 0.030743386433355353

# %% [markdown]
# ### Negative correlation between Attrition and StockOptionLevel

# %%
stats,p = pearsonr(df.Attrition_numerical,df.StockOptionLevel)
print(stats,p)
# Out:
# -0.006838852403261725 0.6498072937477134

# %% [markdown]
# ### Negative correlation between Attrition and TrainingTimesLastYear

# %%
stats,p = pearsonr(df.Attrition_numerical,df.TrainingTimesLastYear)
print(stats,p)
# Out:
# -0.04943057624425515 0.00102470619153603

# %% [markdown]
# ### Negative correlation between Attrition and YearsAtCompany

# %%
stats,p = pearsonr(df.Attrition_numerical,df.YearsAtCompany)
print(stats,p)
# Out:
# -0.13439221398997758 3.1638831224870065e-19

# %% [markdown]
# ### Negative correlation between Attrition and YearsSinceLastPromotion

# %%
stats,p = pearsonr(df.Attrition_numerical,df.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.033018775142584444 0.028330336189402967

# %% [markdown]
# ### Negative correlation between Attrition and YearsWithCurrManager

# %%
stats,p = pearsonr(df.Attrition_numerical,df.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.15619931590162808 1.7339322652900218e-25

# %%
df.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.006963  -0.035706            NaN
# DistanceFromHome         0.006963          1.000000  -0.008638            NaN
# Education               -0.035706         -0.008638   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008649         -0.001097  -0.009680            NaN
# JobLevel                -0.002884         -0.037329   0.045746            NaN
# MonthlyIncome           -0.044314         -0.021607   0.006410            NaN
# NumCompaniesWorked       0.299243         -0.013843  -0.016250            NaN
# PercentSalaryHike       -0.033137          0.038125  -0.040531            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031753          0.011169   0.001261            NaN
# ...

# %% [markdown]
# ### We can even find partial correlation using pingouin module

# %%
from pingouin import partial_corr
partial_corr(data=df, x='Attrition_numerical', y='Age', method='pearson')
# Out:
#             n         r           CI95%        r2    adj_r2         p-val  \
# pearson  4410 -0.159205  [-0.19, -0.13]  0.025346  0.024904  1.996802e-26
#
#               BF10  power
# pearson  6.894e+22    1.0

# %% [markdown]
# ### Correlation heatmap using seaborn

# %%
import seaborn as sns

# %%
plt.figure(figsize = (10,5))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
